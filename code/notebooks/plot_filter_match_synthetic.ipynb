# %%
import os
import numpy as np
from six.moves import cPickle
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # performance

# %%
results_path = os.path.join('../results/', 'synthetic')
file_path = os.path.join(results_path, 'results_synthetic_performance.pickle')
with open(file_path, 'rb') as f:
    results = cPickle.load(f)

# %%
activations = ['relu', 'exponential', 'sigmoid', 'tanh', 'softplus', 'linear',  'elu']
activation_names = ['Relu', 'Exponential', 'Sigmoid', 'Tanh', 'Softplus', 'Linear', 'Elu']

fig = plt.figure(figsize=(7,8))
ax = plt.subplot(3,1,1)
vals = []
for activation in activations:
    vals.append(results['cnn-2'][activation][0])
ax.boxplot(vals);
ax.set_xticklabels([])
plt.ylabel('CNN-2', fontsize=12)
plt.yticks([0.7, .8, 0.9, 1.0], fontsize=12)
#plt.xticks(range(1,len(activations)+1), activations, fontsize=12, rotation=45);

ax = plt.subplot(3,1,2)
vals = []
for activation in activations:
    vals.append(results['cnn-50'][activation][0])
ax.boxplot(vals);
ax.set_xticklabels([])
plt.ylabel('CNN-50', fontsize=12)
plt.yticks([.7, 0.8, 0.9, 1.0], fontsize=12)
#plt.xticks(range(1,len(activations)+1), activations, fontsize=12, rotation=45);

ax = plt.subplot(3,1,3)
vals = []
for activation in activations:
    vals.append(results['cnn-deep'][activation][0])
ax.boxplot(vals);
plt.ylabel('CNN-deep', fontsize=12)
plt.yticks([.7, 0.8, 0.9, 1.0], fontsize=12)
plt.xticks(range(1,len(activations)+1), activation_names, fontsize=12, rotation=45);

outfile = os.path.join(results_path, 'Compare_activations_performance_roc.pdf')
fig.savefig(outfile, format='pdf', dpi=200, bbox_inches='tight')

# %%
activations = ['relu', 'exponential', 'sigmoid', 'tanh', 'softplus', 'linear',  'elu']
activation_names = ['Relu', 'Exponential', 'Sigmoid', 'Tanh', 'Softplus', 'Linear', 'Elu']

fig = plt.figure(figsize=(7,8))
ax = plt.subplot(3,1,1)
vals = []
for activation in activations:
    vals.append(results['cnn-2'][activation][1])
ax.boxplot(vals);
ax.set_xticklabels([])
plt.ylabel('CNN-2', fontsize=12)
plt.yticks([0.4, .6, 0.8, 1.0], fontsize=12)
#plt.xticks(range(1,len(activations)+1), activations, fontsize=12, rotation=45);

ax = plt.subplot(3,1,2)
vals = []
for activation in activations:
    vals.append(results['cnn-50'][activation][1])
ax.boxplot(vals);
ax.set_xticklabels([])
plt.ylabel('CNN-50', fontsize=12)
plt.yticks([.4, 0.6, 0.8, 1.0], fontsize=12)
#plt.xticks(range(1,len(activations)+1), activations, fontsize=12, rotation=45);

ax = plt.subplot(3,1,3)
vals = []
for activation in activations:
    vals.append(results['cnn-deep'][activation][1])
ax.boxplot(vals);
plt.ylabel('CNN-deep', fontsize=12)
plt.yticks([.4, 0.6, 0.8, 1.0], fontsize=12)
plt.xticks(range(1,len(activations)+1), activation_names, fontsize=12, rotation=45);

outfile = os.path.join(results_path, 'Compare_activations_performance_pr.pdf')
fig.savefig(outfile, format='pdf', dpi=200, bbox_inches='tight')

# %% [markdown]
# # filter match comparison

# %%
results_path = os.path.join('../results/', 'synthetic')
file_path = os.path.join(results_path, 'results_synthetic.pickle')
with open(file_path, 'rb') as f:
    results = cPickle.load(f)

# %%
activations = ['relu', 'exponential', 'sigmoid', 'tanh', 'softplus', 'linear',  'elu']
activation_names = ['Relu', 'Exponential', 'Sigmoid', 'Tanh', 'Softplus', 'Linear', 'Elu']

fig = plt.figure(figsize=(7,8))
ax = plt.subplot(3,1,1)
vals = []
for activation in activations:
    vals.append(results['cnn-2_do_l2_bn'][activation]['match_fraction'])
ax.boxplot(vals);
ax.set_xticklabels([])
plt.ylabel('CNN-2', fontsize=12)
plt.yticks([0., .25, 0.5, 0.75, 1.0], fontsize=12)
#plt.xticks(range(1,len(activations)+1), activations, fontsize=12, rotation=45);

ax = plt.subplot(3,1,2)
vals = []
for activation in activations:
    vals.append(results['cnn-50_do_l2_bn'][activation]['match_fraction'])
ax.boxplot(vals);
ax.set_xticklabels([])
plt.ylabel('CNN-50', fontsize=12)
plt.yticks([0., .25, 0.5, 0.75, 1.0], fontsize=12)
#plt.xticks(range(1,len(activations)+1), activations, fontsize=12, rotation=45);

ax = plt.subplot(3,1,3)
vals = []
for activation in activations:
    vals.append(results['cnn-deep_do_l2_bn'][activation]['match_fraction'])
ax.boxplot(vals);
plt.ylabel('CNN-deep', fontsize=12)
plt.yticks([0., .25, 0.5, 0.75, 1.0], fontsize=12)
plt.xticks(range(1,len(activations)+1), activation_names, fontsize=12, rotation=45);

outfile = os.path.join(results_path, 'Compare_activations_match_fraction.pdf')
fig.savefig(outfile, format='pdf', dpi=200, bbox_inches='tight')

# %% [markdown]
# # synthetic other

# %%
results_path = os.path.join('../results/', 'synthetic')
file_path = os.path.join(results_path, 'results_synthetic_other.pickle')
with open(file_path, 'rb') as f:
    results2 = cPickle.load(f)

# %%
results2['cnn-deep_do_l2_bn'].keys()
# Out:
# dict_keys(['exp_relu', 'shift_scale_tanh', 'shift_scale_relu', 'shift_scale_sigmoid', 'shift_relu', 'scale_relu', 'shift_tanh', 'scale_tanh', 'shift_sigmoid', 'scale_sigmoid'])

# %%
activations_other = ['exp_relu', 'shift_scale_tanh', 'shift_scale_relu', 'shift_scale_sigmoid']

# %%
from scipy import stats

fig = plt.figure(figsize=(9,8))
ax = plt.subplot(3,4,1)
vals = []
vals.append(results['cnn-2_do_l2_bn']['sigmoid']['match_fraction'])
vals.append(results2['cnn-2_do_l2_bn']['shift_scale_sigmoid']['match_fraction'])
ax.boxplot(vals,  widths = 0.6);
ax.set_xticklabels([])
plt.ylabel('CNN-2', fontsize=12)
plt.yticks([0., .25, 0.5, 0.75, 1.0], fontsize=12)
#plt.xticks(range(1,len(activations)+1), activations, fontsize=12, rotation=45);
pval = stats.ttest_ind(results['cnn-2_do_l2_bn']['sigmoid']['match_fraction'], 
                       results2['cnn-2_do_l2_bn']['shift_scale_sigmoid']['match_fraction']).pvalue
print(pval)

ax = plt.subplot(3,4,5)
vals = []
vals.append(results['cnn-50_do_l2_bn']['sigmoid']['match_fraction'])
vals.append(results2['cnn-50_do_l2_bn']['shift_scale_sigmoid']['match_fraction'])
ax.boxplot(vals,  widths = 0.6);
ax.set_xticklabels([])
plt.ylabel('CNN-50', fontsize=12)
plt.yticks([0., .25, 0.5, 0.75, 1.0], fontsize=12)
#plt.xticks(range(1,len(activations)+1), activations, fontsize=12, rotation=45);
pval = stats.ttest_ind(results['cnn-50_do_l2_bn']['sigmoid']['match_fraction'], 
                       results2['cnn-50_do_l2_bn']['shift_scale_sigmoid']['match_fraction']).pvalue
print(pval)


ax = plt.subplot(3,4,9)
vals = []
vals.append(results['cnn-deep_do_l2_bn']['sigmoid']['match_fraction'])
vals.append(results2['cnn-deep_do_l2_bn']['shift_scale_sigmoid']['match_fraction'])
ax.boxplot(vals,  widths = 0.6);
plt.ylabel('CNN-deep', fontsize=12)
plt.yticks([0., .25, 0.5, 0.75, 1.0], fontsize=12)
plt.xticks(range(1,3), ['Sigmoid', 'Modified-Sigmoid'], fontsize=12, rotation=45);
pval = stats.ttest_ind(results['cnn-deep_do_l2_bn']['sigmoid']['match_fraction'], 
                       results2['cnn-deep_do_l2_bn']['shift_scale_sigmoid']['match_fraction']).pvalue
print(pval)


ax = plt.subplot(3,4,2)
vals = []
vals.append(results['cnn-2_do_l2_bn']['tanh']['match_fraction'])
vals.append(results2['cnn-2_do_l2_bn']['shift_scale_tanh']['match_fraction'])
ax.boxplot(vals,  widths = 0.6);
ax.set_xticklabels([])
ax.tick_params(labelleft=False) 
plt.yticks([0., .25, 0.5, 0.75, 1.0], fontsize=12)
#plt.xticks(range(1,len(activations)+1), activations, fontsize=12, rotation=45);
pval = stats.ttest_ind(results['cnn-2_do_l2_bn']['tanh']['match_fraction'], 
                       results2['cnn-2_do_l2_bn']['shift_scale_tanh']['match_fraction']).pvalue
print(pval)


ax = plt.subplot(3,4,6)
vals = []
vals.append(results['cnn-50_do_l2_bn']['tanh']['match_fraction'])
vals.append(results2['cnn-50_do_l2_bn']['shift_scale_tanh']['match_fraction'])
ax.boxplot(vals,  widths = 0.6);
ax.set_xticklabels([])
ax.tick_params(labelleft=False) 
plt.yticks([0., .25, 0.5, 0.75, 1.0], fontsize=12)
#plt.xticks(range(1,len(activations)+1), activations, fontsize=12, rotation=45);
pval = stats.ttest_ind(results['cnn-50_do_l2_bn']['tanh']['match_fraction'], 
                       results2['cnn-50_do_l2_bn']['shift_scale_tanh']['match_fraction']).pvalue
print(pval)

ax = plt.subplot(3,4,10)
vals = []
vals.append(results['cnn-deep_do_l2_bn']['tanh']['match_fraction'])
vals.append(results2['cnn-deep_do_l2_bn']['shift_scale_tanh']['match_fraction'])
ax.boxplot(vals,  widths = 0.6);
plt.yticks([0., .25, 0.5, 0.75, 1.0], fontsize=12)
ax.tick_params(labelleft=False) 
plt.xticks(range(1,3), ['Tanh', 'Modified-Tanh'], fontsize=12, rotation=45);
pval = stats.ttest_ind(results['cnn-deep_do_l2_bn']['tanh']['match_fraction'], 
                       results2['cnn-deep_do_l2_bn']['shift_scale_tanh']['match_fraction']).pvalue
print(pval)


ax = plt.subplot(3,4,3)
vals = []
vals.append(results['cnn-2_do_l2_bn']['relu']['match_fraction'])
vals.append(results2['cnn-2_do_l2_bn']['shift_scale_relu']['match_fraction'])
ax.boxplot(vals,  widths = 0.6);
ax.set_xticklabels([])
ax.tick_params(labelleft=False) 
plt.yticks([0., .25, 0.5, 0.75, 1.0], fontsize=12)
#plt.xticks(range(1,len(activations)+1), activations, fontsize=12, rotation=45);
pval = stats.ttest_ind(results['cnn-2_do_l2_bn']['relu']['match_fraction'], 
                       results2['cnn-2_do_l2_bn']['shift_scale_relu']['match_fraction']).pvalue
print(pval)

ax = plt.subplot(3,4,7)
vals = []
vals.append(results['cnn-50_do_l2_bn']['relu']['match_fraction'])
vals.append(results2['cnn-50_do_l2_bn']['shift_scale_relu']['match_fraction'])
ax.boxplot(vals,  widths = 0.6);
ax.set_xticklabels([])
ax.tick_params(labelleft=False) 
plt.yticks([0., .25, 0.5, 0.75, 1.0], fontsize=12)
#plt.xticks(range(1,len(activations)+1), activations, fontsize=12, rotation=45);
pval = stats.ttest_ind(results['cnn-50_do_l2_bn']['relu']['match_fraction'], 
                       results2['cnn-50_do_l2_bn']['shift_scale_relu']['match_fraction']).pvalue
print(pval)

ax = plt.subplot(3,4,11)
vals = []
vals.append(results['cnn-deep_do_l2_bn']['relu']['match_fraction'])
vals.append(results2['cnn-deep_do_l2_bn']['shift_scale_relu']['match_fraction'])
ax.boxplot(vals,  widths = 0.6);
plt.yticks([0., .25, 0.5, 0.75, 1.0], fontsize=12)
ax.tick_params(labelleft=False) 
plt.xticks(range(1,3), ['Relu', 'Modified-Relu'], fontsize=12, rotation=45);
pval = stats.ttest_ind(results['cnn-deep_do_l2_bn']['relu']['match_fraction'], 
                       results2['cnn-deep_do_l2_bn']['shift_scale_relu']['match_fraction']).pvalue
print(pval)


ax = plt.subplot(3,4,4)
vals = []
vals.append(results['cnn-2_do_l2_bn']['exponential']['match_fraction'])
vals.append(results2['cnn-2_do_l2_bn']['exp_relu']['match_fraction'])
ax.boxplot(vals,  widths = 0.6);
ax.set_xticklabels([])
ax.tick_params(labelleft=False) 
plt.yticks([0., .25, 0.5, 0.75, 1.0], fontsize=12)
#plt.xticks(range(1,len(activations)+1), activations, fontsize=12, rotation=45);
pval = stats.ttest_ind(results['cnn-2_do_l2_bn']['exponential']['match_fraction'], 
                       results2['cnn-2_do_l2_bn']['exp_relu']['match_fraction']).pvalue
print(pval)

ax = plt.subplot(3,4,8)
vals = []
vals.append(results['cnn-50_do_l2_bn']['exponential']['match_fraction'])
vals.append(results2['cnn-50_do_l2_bn']['exp_relu']['match_fraction'])
ax.boxplot(vals,  widths = 0.6);
ax.set_xticklabels([])
ax.tick_params(labelleft=False) 
plt.yticks([0., .25, 0.5, 0.75, 1.0], fontsize=12)
#plt.xticks(range(1,len(activations)+1), activations, fontsize=12, rotation=45);
pval = stats.ttest_ind(results['cnn-50_do_l2_bn']['exponential']['match_fraction'], 
                       results2['cnn-50_do_l2_bn']['exp_relu']['match_fraction']).pvalue
print(pval)

ax = plt.subplot(3,4,12)
vals = []
vals.append(results['cnn-deep_do_l2_bn']['exponential']['match_fraction'])
vals.append(results2['cnn-deep_do_l2_bn']['exp_relu']['match_fraction'])
ax.boxplot(vals,  widths = 0.6);
plt.yticks([0., .25, 0.5, 0.75, 1.0], fontsize=12)
ax.tick_params(labelleft=False) 
plt.xticks(range(1,3), ['Exp', 'Modified-Exp'], fontsize=12, rotation=45);
pval = stats.ttest_ind(results['cnn-deep_do_l2_bn']['exponential']['match_fraction'], 
                       results2['cnn-deep_do_l2_bn']['exp_relu']['match_fraction']).pvalue
print(pval)

outfile = os.path.join(results_path, 'synthetic_Compare_activations_match_fraction_other.pdf')
fig.savefig(outfile, format='pdf', dpi=200, bbox_inches='tight')
# Out:
# 8.220114906458314e-23
# 1.0299214116193245e-13
# 2.8709956849109856e-22
# 1.7486490391773766e-20
# 3.8353741366480095e-10
# 1.355853752895881e-16
# 2.1606709996377623e-28
# 0.4031981359139446
# 3.321714611819677e-26
# 8.629238613077112e-23
# 0.14193549786957363
# 7.72596580147287e-23

# %%
outfile
# Out:
# '../results/synthetic/synthetic_Compare_activations_match_fraction_other.pdf'

# %%
results2['cnn-2_do_l2_bn'].keys()
# Out:
# dict_keys(['exp_relu', 'shift_scale_tanh', 'shift_scale_relu', 'shift_scale_sigmoid', 'shift_relu', 'scale_relu', 'shift_tanh', 'scale_tanh', 'shift_sigmoid', 'scale_sigmoid'])

# %%
from scipy import stats

fig = plt.figure(figsize=(11,8))
ax = plt.subplot(3,3,1)
vals = []
vals.append(results['cnn-2_do_l2_bn']['sigmoid']['match_fraction'])
vals.append(results2['cnn-2_do_l2_bn']['shift_sigmoid']['match_fraction'])
vals.append(results2['cnn-2_do_l2_bn']['scale_sigmoid']['match_fraction'])
vals.append(results2['cnn-2_do_l2_bn']['shift_scale_sigmoid']['match_fraction'])
ax.boxplot(vals,  widths = 0.6);
ax.set_xticklabels([])
plt.ylabel('CNN-2', fontsize=12)
plt.yticks([0., .25, 0.5, 0.75, 1.0], fontsize=12)
plt.title('Sigmoid', fontsize=12)

ax = plt.subplot(3,3,4)
vals = []
vals.append(results['cnn-50_do_l2_bn']['sigmoid']['match_fraction'])
vals.append(results2['cnn-50_do_l2_bn']['shift_sigmoid']['match_fraction'])
vals.append(results2['cnn-50_do_l2_bn']['scale_sigmoid']['match_fraction'])
vals.append(results2['cnn-50_do_l2_bn']['shift_scale_sigmoid']['match_fraction'])
ax.boxplot(vals,  widths = 0.6);
ax.set_xticklabels([])
plt.ylabel('CNN-50', fontsize=12)
plt.yticks([0., .25, 0.5, 0.75, 1.0], fontsize=12)
#plt.xticks(range(1,len(activations)+1), activations, fontsize=12, rotation=45);


ax = plt.subplot(3,3,7)
vals = []
vals.append(results['cnn-deep_do_l2_bn']['sigmoid']['match_fraction'])
vals.append(results2['cnn-deep_do_l2_bn']['shift_sigmoid']['match_fraction'])
vals.append(results2['cnn-deep_do_l2_bn']['scale_sigmoid']['match_fraction'])
vals.append(results2['cnn-deep_do_l2_bn']['shift_scale_sigmoid']['match_fraction'])
ax.boxplot(vals,  widths = 0.6);
plt.ylabel('CNN-deep', fontsize=12)
plt.yticks([0., .25, 0.5, 0.75, 1.0], fontsize=12)
plt.xticks(range(1,5), ['Original', 'Shift', 'Scale', 'Shift+Scale'], fontsize=12, rotation=45);


ax = plt.subplot(3,3,2)
vals = []
vals.append(results['cnn-2_do_l2_bn']['tanh']['match_fraction'])
vals.append(results2['cnn-2_do_l2_bn']['shift_tanh']['match_fraction'])
vals.append(results2['cnn-2_do_l2_bn']['scale_tanh']['match_fraction'])
vals.append(results2['cnn-2_do_l2_bn']['shift_scale_tanh']['match_fraction'])
ax.boxplot(vals,  widths = 0.6);
ax.set_xticklabels([])
ax.tick_params(labelleft=False) 
plt.yticks([0., .25, 0.5, 0.75, 1.0], fontsize=12)
#plt.xticks(range(1,len(activations)+1), activations, fontsize=12, rotation=45);
plt.title('Tanh', fontsize=12)



ax = plt.subplot(3,3,5)
vals = []
vals.append(results['cnn-50_do_l2_bn']['tanh']['match_fraction'])
vals.append(results2['cnn-50_do_l2_bn']['shift_tanh']['match_fraction'])
vals.append(results2['cnn-50_do_l2_bn']['scale_tanh']['match_fraction'])
vals.append(results2['cnn-50_do_l2_bn']['shift_scale_tanh']['match_fraction'])
ax.boxplot(vals,  widths = 0.6);
ax.set_xticklabels([])
ax.tick_params(labelleft=False) 
plt.yticks([0., .25, 0.5, 0.75, 1.0], fontsize=12)
#plt.xticks(range(1,len(activations)+1), activations, fontsize=12, rotation=45);


ax = plt.subplot(3,3,8)
vals = []
vals.append(results['cnn-deep_do_l2_bn']['tanh']['match_fraction'])
vals.append(results2['cnn-deep_do_l2_bn']['shift_tanh']['match_fraction'])
vals.append(results2['cnn-deep_do_l2_bn']['scale_tanh']['match_fraction'])
vals.append(results2['cnn-deep_do_l2_bn']['shift_scale_tanh']['match_fraction'])
ax.boxplot(vals,  widths = 0.6);
plt.yticks([0., .25, 0.5, 0.75, 1.0], fontsize=12)
ax.tick_params(labelleft=False) 
plt.xticks(range(1,5), ['Original', 'Shift', 'Scale', 'Shift+Scale'], fontsize=12, rotation=45);



ax = plt.subplot(3,3,3)
vals = []
vals.append(results['cnn-2_do_l2_bn']['relu']['match_fraction'])
vals.append(results2['cnn-2_do_l2_bn']['shift_relu']['match_fraction'])
vals.append(results2['cnn-2_do_l2_bn']['scale_relu']['match_fraction'])
vals.append(results2['cnn-2_do_l2_bn']['shift_scale_relu']['match_fraction'])
ax.boxplot(vals,  widths = 0.6);
ax.set_xticklabels([])
ax.tick_params(labelleft=False) 
plt.yticks([0., .25, 0.5, 0.75, 1.0], fontsize=12)
#plt.xticks(range(1,len(activations)+1), activations, fontsize=12, rotation=45);
plt.title('Relu', fontsize=12)


ax = plt.subplot(3,3,6)
vals = []
vals.append(results['cnn-50_do_l2_bn']['relu']['match_fraction'])
vals.append(results2['cnn-50_do_l2_bn']['shift_relu']['match_fraction'])
vals.append(results2['cnn-50_do_l2_bn']['scale_relu']['match_fraction'])
vals.append(results2['cnn-50_do_l2_bn']['shift_scale_relu']['match_fraction'])
ax.boxplot(vals,  widths = 0.6);
ax.set_xticklabels([])
ax.tick_params(labelleft=False) 
plt.yticks([0., .25, 0.5, 0.75, 1.0], fontsize=12)
#plt.xticks(range(1,len(activations)+1), activations, fontsize=12, rotation=45);

ax = plt.subplot(3,3,9)
vals = []
vals.append(results['cnn-deep_do_l2_bn']['relu']['match_fraction'])
vals.append(results2['cnn-deep_do_l2_bn']['shift_relu']['match_fraction'])
vals.append(results2['cnn-deep_do_l2_bn']['scale_relu']['match_fraction'])
vals.append(results2['cnn-deep_do_l2_bn']['shift_scale_relu']['match_fraction'])
ax.boxplot(vals,  widths = 0.6);
plt.yticks([0., .25, 0.5, 0.75, 1.0], fontsize=12)
ax.tick_params(labelleft=False) 
plt.xticks(range(1,5), ['Original', 'Shift', 'Scale', 'Shift+Scale'], fontsize=12, rotation=45);

outfile = os.path.join(results_path, 'synthetic_Compare_activations_match_fraction_other_ablation.pdf')
fig.savefig(outfile, format='pdf', dpi=200, bbox_inches='tight')

# %%
from scipy import stats
pval = stats.ttest_ind(results['cnn-50_do_l2_bn']['exponential']['match_fraction'], results2['cnn-50_do_l2_bn']['exp_01']['match_fraction']).pvalue

# %%
activations = ['relu', 'exponential', 'sigmoid', 'tanh', 'softplus', 'linear']

fig = plt.figure(figsize=(10,8))
ax = plt.subplot(3,1,1)
vals = []
for activation in activations:
    vals.append(results['cnn-50_do_l2_bn'][activation]['match_any'])
ax.boxplot(vals);
ax.set_xticklabels([])
plt.ylabel('CNN-2', fontsize=12)
plt.yticks([0., .25, 0.5, 0.75, 1.0], fontsize=12)
#plt.xticks(range(1,len(activations)+1), activations, fontsize=12, rotation=45);

ax = plt.subplot(3,1,2)
vals = []
for activation in activations:
    vals.append(results['cnn-50_do_l2_bn'][activation]['match_any'])
ax.boxplot(vals);
ax.set_xticklabels([])
plt.ylabel('CNN-50', fontsize=12)
plt.yticks([0., .25, 0.5, 0.75, 1.0], fontsize=12)
#plt.xticks(range(1,len(activations)+1), activations, fontsize=12, rotation=45);

ax = plt.subplot(3,1,3)
vals = []
for activation in activations:
    vals.append(results['cnn-deep_do_l2_bn'][activation]['match_any'])
ax.boxplot(vals);
plt.ylabel('CNN-deep', fontsize=12)
plt.yticks([0., .25, 0.5, 0.75, 1.0], fontsize=12)
plt.xticks(range(1,len(activations)+1), activations, fontsize=12, rotation=45);

outfile = os.path.join(results_path, 'Compare_activations_match_fraction_any')
fig.savefig(outfile, format='pdf', dpi=200, bbox_inches='tight')
