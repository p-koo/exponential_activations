# %%
import os
import numpy as np
from six.moves import cPickle
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # performance

# %%
results_path = os.path.join('../results/', 'task1')
file_path = os.path.join(results_path, 'task1_filter_results.pickle')
with open(file_path, 'rb') as f:
    results = cPickle.load(f)

# %%
activations = ['relu', 'exponential', 'sigmoid', 'tanh', 'softplus', 'linear',  'elu']
activation_names = ['Relu', 'Exponential', 'Sigmoid', 'Tanh', 'Softplus', 'Linear', 'Elu']

fig = plt.figure(figsize=(7,8))
ax = plt.subplot(3,1,1)
vals = []
for activation in activations:
    vals.append(results['cnn-2'][activation][0])
ax.boxplot(vals);
ax.set_xticklabels([])
plt.ylabel('CNN-2', fontsize=12)
plt.yticks([0.7, .8, 0.9, 1.0], fontsize=12)
#plt.xticks(range(1,len(activations)+1), activations, fontsize=12, rotation=45);

ax = plt.subplot(3,1,2)
vals = []
for activation in activations:
    vals.append(results['cnn-50'][activation][0])
ax.boxplot(vals);
ax.set_xticklabels([])
plt.ylabel('CNN-50', fontsize=12)
plt.yticks([.7, 0.8, 0.9, 1.0], fontsize=12)
#plt.xticks(range(1,len(activations)+1), activations, fontsize=12, rotation=45);

ax = plt.subplot(3,1,3)
vals = []
for activation in activations:
    vals.append(results['cnn-deep'][activation][0])
ax.boxplot(vals);
plt.ylabel('CNN-deep', fontsize=12)
plt.yticks([.7, 0.8, 0.9, 1.0], fontsize=12)
plt.xticks(range(1,len(activations)+1), activation_names, fontsize=12, rotation=45);

outfile = os.path.join(results_path, 'task1_performance_roc.pdf')
fig.savefig(outfile, format='pdf', dpi=200, bbox_inches='tight')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-6-69dcf1758140> in <module>
#       6 vals = []
#       7 for activation in activations:
# ----> 8     vals.append(results['cnn-2'][activation][0])
#       9 ax.boxplot(vals);
#      10 ax.set_xticklabels([])
#
# KeyError: 0

# %%
activations = ['relu', 'exponential', 'sigmoid', 'tanh', 'softplus', 'linear',  'elu']
activation_names = ['Relu', 'Exponential', 'Sigmoid', 'Tanh', 'Softplus', 'Linear', 'Elu']

fig = plt.figure(figsize=(7,8))
ax = plt.subplot(3,1,1)
vals = []
for activation in activations:
    vals.append(results['cnn-2'][activation][1])
ax.boxplot(vals);
ax.set_xticklabels([])
plt.ylabel('CNN-2', fontsize=12)
plt.yticks([0.4, .6, 0.8, 1.0], fontsize=12)
#plt.xticks(range(1,len(activations)+1), activations, fontsize=12, rotation=45);

ax = plt.subplot(3,1,2)
vals = []
for activation in activations:
    vals.append(results['cnn-50'][activation][1])
ax.boxplot(vals);
ax.set_xticklabels([])
plt.ylabel('CNN-50', fontsize=12)
plt.yticks([.4, 0.6, 0.8, 1.0], fontsize=12)
#plt.xticks(range(1,len(activations)+1), activations, fontsize=12, rotation=45);

ax = plt.subplot(3,1,3)
vals = []
for activation in activations:
    vals.append(results['cnn-deep'][activation][1])
ax.boxplot(vals);
plt.ylabel('CNN-deep', fontsize=12)
plt.yticks([.4, 0.6, 0.8, 1.0], fontsize=12)
plt.xticks(range(1,len(activations)+1), activation_names, fontsize=12, rotation=45);

outfile = os.path.join(results_path, 'task1_performance_pr.pdf')
fig.savefig(outfile, format='pdf', dpi=200, bbox_inches='tight')

# %% [markdown]
# # filter match comparison

# %%
results_path = os.path.join('../results/', 'task1')
file_path = os.path.join(results_path, 'task1_filter_results.pickle')
with open(file_path, 'rb') as f:
    results = cPickle.load(f)

# %%
activations = ['relu', 'exponential', 'sigmoid', 'tanh', 'softplus', 'linear',  'elu']
activation_names = ['Relu', 'Exponential', 'Sigmoid', 'Tanh', 'Softplus', 'Linear', 'Elu']

fig = plt.figure(figsize=(7,8))
ax = plt.subplot(3,1,1)
vals = []
for activation in activations:
    vals.append(results['cnn-2'][activation]['match_fraction'])
ax.boxplot(vals);
ax.set_xticklabels([])
plt.ylabel('CNN-2', fontsize=12)
plt.yticks([0., .25, 0.5, 0.75, 1.0], fontsize=12)
#plt.xticks(range(1,len(activations)+1), activations, fontsize=12, rotation=45);

ax = plt.subplot(3,1,2)
vals = []
for activation in activations:
    vals.append(results['cnn-50'][activation]['match_fraction'])
ax.boxplot(vals);
ax.set_xticklabels([])
plt.ylabel('CNN-50', fontsize=12)
plt.yticks([0., .25, 0.5, 0.75, 1.0], fontsize=12)
#plt.xticks(range(1,len(activations)+1), activations, fontsize=12, rotation=45);

ax = plt.subplot(3,1,3)
vals = []
for activation in activations:
    vals.append(results['cnn-deep'][activation]['match_fraction'])
ax.boxplot(vals);
plt.ylabel('CNN-deep', fontsize=12)
plt.yticks([0., .25, 0.5, 0.75, 1.0], fontsize=12)
plt.xticks(range(1,len(activations)+1), activation_names, fontsize=12, rotation=45);

outfile = os.path.join(results_path, 'task1_filter_match.pdf')
fig.savefig(outfile, format='pdf', dpi=200, bbox_inches='tight')

# %% [markdown]
# # synthetic other

# %%
from scipy import stats

fig = plt.figure(figsize=(9,8))
ax = plt.subplot(3,4,1)
vals = []
vals.append(results['cnn-2']['sigmoid']['match_fraction'])
vals.append(results['cnn-2']['shift_scale_sigmoid']['match_fraction'])
ax.boxplot(vals,  widths = 0.6);
ax.set_xticklabels([])
plt.ylabel('CNN-2', fontsize=12)
plt.yticks([0., .25, 0.5, 0.75, 1.0], fontsize=12)
#plt.xticks(range(1,len(activations)+1), activations, fontsize=12, rotation=45);
pval = stats.ttest_ind(results['cnn-2']['sigmoid']['match_fraction'], 
                       results2['cnn-2']['shift_scale_sigmoid']['match_fraction']).pvalue
print(pval)

ax = plt.subplot(3,4,5)
vals = []
vals.append(results['cnn-50']['sigmoid']['match_fraction'])
vals.append(results2['cnn-50']['shift_scale_sigmoid']['match_fraction'])
ax.boxplot(vals,  widths = 0.6);
ax.set_xticklabels([])
plt.ylabel('CNN-50', fontsize=12)
plt.yticks([0., .25, 0.5, 0.75, 1.0], fontsize=12)
#plt.xticks(range(1,len(activations)+1), activations, fontsize=12, rotation=45);
pval = stats.ttest_ind(results['cnn-50']['sigmoid']['match_fraction'], 
                       results2['cnn-50']['shift_scale_sigmoid']['match_fraction']).pvalue
print(pval)


ax = plt.subplot(3,4,9)
vals = []
vals.append(results['cnn-deep']['sigmoid']['match_fraction'])
vals.append(results2['cnn-deep']['shift_scale_sigmoid']['match_fraction'])
ax.boxplot(vals,  widths = 0.6);
plt.ylabel('CNN-deep', fontsize=12)
plt.yticks([0., .25, 0.5, 0.75, 1.0], fontsize=12)
plt.xticks(range(1,3), ['Sigmoid', 'Modified-Sigmoid'], fontsize=12, rotation=45);
pval = stats.ttest_ind(results['cnn-deep']['sigmoid']['match_fraction'], 
                       results2['cnn-deep']['shift_scale_sigmoid']['match_fraction']).pvalue
print(pval)


ax = plt.subplot(3,4,2)
vals = []
vals.append(results['cnn-2']['tanh']['match_fraction'])
vals.append(results2['cnn-2']['shift_scale_tanh']['match_fraction'])
ax.boxplot(vals,  widths = 0.6);
ax.set_xticklabels([])
ax.tick_params(labelleft=False) 
plt.yticks([0., .25, 0.5, 0.75, 1.0], fontsize=12)
#plt.xticks(range(1,len(activations)+1), activations, fontsize=12, rotation=45);
pval = stats.ttest_ind(results['cnn-2']['tanh']['match_fraction'], 
                       results2['cnn-2']['shift_scale_tanh']['match_fraction']).pvalue
print(pval)


ax = plt.subplot(3,4,6)
vals = []
vals.append(results['cnn-50']['tanh']['match_fraction'])
vals.append(results2['cnn-50']['shift_scale_tanh']['match_fraction'])
ax.boxplot(vals,  widths = 0.6);
ax.set_xticklabels([])
ax.tick_params(labelleft=False) 
plt.yticks([0., .25, 0.5, 0.75, 1.0], fontsize=12)
#plt.xticks(range(1,len(activations)+1), activations, fontsize=12, rotation=45);
pval = stats.ttest_ind(results['cnn-50']['tanh']['match_fraction'], 
                       results2['cnn-50']['shift_scale_tanh']['match_fraction']).pvalue
print(pval)

ax = plt.subplot(3,4,10)
vals = []
vals.append(results['cnn-deep']['tanh']['match_fraction'])
vals.append(results2['cnn-deep']['shift_scale_tanh']['match_fraction'])
ax.boxplot(vals,  widths = 0.6);
plt.yticks([0., .25, 0.5, 0.75, 1.0], fontsize=12)
ax.tick_params(labelleft=False) 
plt.xticks(range(1,3), ['Tanh', 'Modified-Tanh'], fontsize=12, rotation=45);
pval = stats.ttest_ind(results['cnn-deep']['tanh']['match_fraction'], 
                       results2['cnn-deep']['shift_scale_tanh']['match_fraction']).pvalue
print(pval)


ax = plt.subplot(3,4,3)
vals = []
vals.append(results['cnn-2']['relu']['match_fraction'])
vals.append(results2['cnn-2']['shift_scale_relu']['match_fraction'])
ax.boxplot(vals,  widths = 0.6);
ax.set_xticklabels([])
ax.tick_params(labelleft=False) 
plt.yticks([0., .25, 0.5, 0.75, 1.0], fontsize=12)
#plt.xticks(range(1,len(activations)+1), activations, fontsize=12, rotation=45);
pval = stats.ttest_ind(results['cnn-2']['relu']['match_fraction'], 
                       results2['cnn-2']['shift_scale_relu']['match_fraction']).pvalue
print(pval)

ax = plt.subplot(3,4,7)
vals = []
vals.append(results['cnn-50']['relu']['match_fraction'])
vals.append(results2['cnn-50']['shift_scale_relu']['match_fraction'])
ax.boxplot(vals,  widths = 0.6);
ax.set_xticklabels([])
ax.tick_params(labelleft=False) 
plt.yticks([0., .25, 0.5, 0.75, 1.0], fontsize=12)
#plt.xticks(range(1,len(activations)+1), activations, fontsize=12, rotation=45);
pval = stats.ttest_ind(results['cnn-50']['relu']['match_fraction'], 
                       results2['cnn-50']['shift_scale_relu']['match_fraction']).pvalue
print(pval)

ax = plt.subplot(3,4,11)
vals = []
vals.append(results['cnn-deep']['relu']['match_fraction'])
vals.append(results2['cnn-deep']['shift_scale_relu']['match_fraction'])
ax.boxplot(vals,  widths = 0.6);
plt.yticks([0., .25, 0.5, 0.75, 1.0], fontsize=12)
ax.tick_params(labelleft=False) 
plt.xticks(range(1,3), ['Relu', 'Modified-Relu'], fontsize=12, rotation=45);
pval = stats.ttest_ind(results['cnn-deep']['relu']['match_fraction'], 
                       results2['cnn-deep']['shift_scale_relu']['match_fraction']).pvalue
print(pval)


ax = plt.subplot(3,4,4)
vals = []
vals.append(results['cnn-2']['exponential']['match_fraction'])
vals.append(results2['cnn-2']['exp_relu']['match_fraction'])
ax.boxplot(vals,  widths = 0.6);
ax.set_xticklabels([])
ax.tick_params(labelleft=False) 
plt.yticks([0., .25, 0.5, 0.75, 1.0], fontsize=12)
#plt.xticks(range(1,len(activations)+1), activations, fontsize=12, rotation=45);
pval = stats.ttest_ind(results['cnn-2']['exponential']['match_fraction'], 
                       results2['cnn-2']['exp_relu']['match_fraction']).pvalue
print(pval)

ax = plt.subplot(3,4,8)
vals = []
vals.append(results['cnn-50']['exponential']['match_fraction'])
vals.append(results2['cnn-50']['exp_relu']['match_fraction'])
ax.boxplot(vals,  widths = 0.6);
ax.set_xticklabels([])
ax.tick_params(labelleft=False) 
plt.yticks([0., .25, 0.5, 0.75, 1.0], fontsize=12)
#plt.xticks(range(1,len(activations)+1), activations, fontsize=12, rotation=45);
pval = stats.ttest_ind(results['cnn-50']['exponential']['match_fraction'], 
                       results2['cnn-50']['exp_relu']['match_fraction']).pvalue
print(pval)

ax = plt.subplot(3,4,12)
vals = []
vals.append(results['cnn-deep']['exponential']['match_fraction'])
vals.append(results2['cnn-deep']['exp_relu']['match_fraction'])
ax.boxplot(vals,  widths = 0.6);
plt.yticks([0., .25, 0.5, 0.75, 1.0], fontsize=12)
ax.tick_params(labelleft=False) 
plt.xticks(range(1,3), ['Exp', 'Modified-Exp'], fontsize=12, rotation=45);
pval = stats.ttest_ind(results['cnn-deep']['exponential']['match_fraction'], 
                       results2['cnn-deep']['exp_relu']['match_fraction']).pvalue
print(pval)

outfile = os.path.join(results_path, 'task1_filter_match_modified_activations.pdf')
fig.savefig(outfile, format='pdf', dpi=200, bbox_inches='tight')
# Out:
# 8.220114906458314e-23
# 1.0299214116193245e-13
# 2.8709956849109856e-22
# 1.7486490391773766e-20
# 3.8353741366480095e-10
# 1.355853752895881e-16
# 2.1606709996377623e-28
# 0.4031981359139446
# 3.321714611819677e-26
# 8.629238613077112e-23
# 0.14193549786957363
# 7.72596580147287e-23

# %%
outfile
# Out:
# '../results/synthetic/synthetic_Compare_activations_match_fraction_other.pdf'

# %%
results2['cnn-2_do_l2_bn'].keys()
# Out:
# dict_keys(['exp_relu', 'shift_scale_tanh', 'shift_scale_relu', 'shift_scale_sigmoid', 'shift_relu', 'scale_relu', 'shift_tanh', 'scale_tanh', 'shift_sigmoid', 'scale_sigmoid'])

# %%
from scipy import stats

fig = plt.figure(figsize=(11,8))
ax = plt.subplot(3,3,1)
vals = []
vals.append(results['cnn-2']['sigmoid']['match_fraction'])
vals.append(results2['cnn-2']['shift_sigmoid']['match_fraction'])
vals.append(results2['cnn-2']['scale_sigmoid']['match_fraction'])
vals.append(results2['cnn-2']['shift_scale_sigmoid']['match_fraction'])
ax.boxplot(vals,  widths = 0.6);
ax.set_xticklabels([])
plt.ylabel('CNN-2', fontsize=12)
plt.yticks([0., .25, 0.5, 0.75, 1.0], fontsize=12)
plt.title('Sigmoid', fontsize=12)

ax = plt.subplot(3,3,4)
vals = []
vals.append(results['cnn-50']['sigmoid']['match_fraction'])
vals.append(results2['cnn-50']['shift_sigmoid']['match_fraction'])
vals.append(results2['cnn-50']['scale_sigmoid']['match_fraction'])
vals.append(results2['cnn-50']['shift_scale_sigmoid']['match_fraction'])
ax.boxplot(vals,  widths = 0.6);
ax.set_xticklabels([])
plt.ylabel('CNN-50', fontsize=12)
plt.yticks([0., .25, 0.5, 0.75, 1.0], fontsize=12)
#plt.xticks(range(1,len(activations)+1), activations, fontsize=12, rotation=45);


ax = plt.subplot(3,3,7)
vals = []
vals.append(results['cnn-deep']['sigmoid']['match_fraction'])
vals.append(results2['cnn-deep']['shift_sigmoid']['match_fraction'])
vals.append(results2['cnn-deep']['scale_sigmoid']['match_fraction'])
vals.append(results2['cnn-deep']['shift_scale_sigmoid']['match_fraction'])
ax.boxplot(vals,  widths = 0.6);
plt.ylabel('CNN-deep', fontsize=12)
plt.yticks([0., .25, 0.5, 0.75, 1.0], fontsize=12)
plt.xticks(range(1,5), ['Original', 'Shift', 'Scale', 'Shift+Scale'], fontsize=12, rotation=45);


ax = plt.subplot(3,3,2)
vals = []
vals.append(results['cnn-2']['tanh']['match_fraction'])
vals.append(results2['cnn-2']['shift_tanh']['match_fraction'])
vals.append(results2['cnn-2']['scale_tanh']['match_fraction'])
vals.append(results2['cnn-2']['shift_scale_tanh']['match_fraction'])
ax.boxplot(vals,  widths = 0.6);
ax.set_xticklabels([])
ax.tick_params(labelleft=False) 
plt.yticks([0., .25, 0.5, 0.75, 1.0], fontsize=12)
#plt.xticks(range(1,len(activations)+1), activations, fontsize=12, rotation=45);
plt.title('Tanh', fontsize=12)



ax = plt.subplot(3,3,5)
vals = []
vals.append(results['cnn-50']['tanh']['match_fraction'])
vals.append(results2['cnn-50']['shift_tanh']['match_fraction'])
vals.append(results2['cnn-50']['scale_tanh']['match_fraction'])
vals.append(results2['cnn-50']['shift_scale_tanh']['match_fraction'])
ax.boxplot(vals,  widths = 0.6);
ax.set_xticklabels([])
ax.tick_params(labelleft=False) 
plt.yticks([0., .25, 0.5, 0.75, 1.0], fontsize=12)
#plt.xticks(range(1,len(activations)+1), activations, fontsize=12, rotation=45);


ax = plt.subplot(3,3,8)
vals = []
vals.append(results['cnn-deep']['tanh']['match_fraction'])
vals.append(results2['cnn-deep']['shift_tanh']['match_fraction'])
vals.append(results2['cnn-deep']['scale_tanh']['match_fraction'])
vals.append(results2['cnn-deep']['shift_scale_tanh']['match_fraction'])
ax.boxplot(vals,  widths = 0.6);
plt.yticks([0., .25, 0.5, 0.75, 1.0], fontsize=12)
ax.tick_params(labelleft=False) 
plt.xticks(range(1,5), ['Original', 'Shift', 'Scale', 'Shift+Scale'], fontsize=12, rotation=45);



ax = plt.subplot(3,3,3)
vals = []
vals.append(results['cnn-2']['relu']['match_fraction'])
vals.append(results2['cnn-2']['shift_relu']['match_fraction'])
vals.append(results2['cnn-2']['scale_relu']['match_fraction'])
vals.append(results2['cnn-2']['shift_scale_relu']['match_fraction'])
ax.boxplot(vals,  widths = 0.6);
ax.set_xticklabels([])
ax.tick_params(labelleft=False) 
plt.yticks([0., .25, 0.5, 0.75, 1.0], fontsize=12)
#plt.xticks(range(1,len(activations)+1), activations, fontsize=12, rotation=45);
plt.title('Relu', fontsize=12)


ax = plt.subplot(3,3,6)
vals = []
vals.append(results['cnn-50']['relu']['match_fraction'])
vals.append(results2['cnn-50']['shift_relu']['match_fraction'])
vals.append(results2['cnn-50']['scale_relu']['match_fraction'])
vals.append(results2['cnn-50']['shift_scale_relu']['match_fraction'])
ax.boxplot(vals,  widths = 0.6);
ax.set_xticklabels([])
ax.tick_params(labelleft=False) 
plt.yticks([0., .25, 0.5, 0.75, 1.0], fontsize=12)
#plt.xticks(range(1,len(activations)+1), activations, fontsize=12, rotation=45);

ax = plt.subplot(3,3,9)
vals = []
vals.append(results['cnn-deep']['relu']['match_fraction'])
vals.append(results2['cnn-deep']['shift_relu']['match_fraction'])
vals.append(results2['cnn-deep']['scale_relu']['match_fraction'])
vals.append(results2['cnn-deep']['shift_scale_relu']['match_fraction'])
ax.boxplot(vals,  widths = 0.6);
plt.yticks([0., .25, 0.5, 0.75, 1.0], fontsize=12)
ax.tick_params(labelleft=False) 
plt.xticks(range(1,5), ['Original', 'Shift', 'Scale', 'Shift+Scale'], fontsize=12, rotation=45);

outfile = os.path.join(results_path, 'task1_filter_match_ablation.pdf')
fig.savefig(outfile, format='pdf', dpi=200, bbox_inches='tight')

# %% [markdown]
# # Compare match fraction to any motif in JASPAR

# %%
activations = ['relu', 'exponential', 'sigmoid', 'tanh', 'softplus', 'linear']

fig = plt.figure(figsize=(10,8))
ax = plt.subplot(3,1,1)
vals = []
for activation in activations:
    vals.append(results['cnn-50'][activation]['match_any'])
ax.boxplot(vals);
ax.set_xticklabels([])
plt.ylabel('CNN-2', fontsize=12)
plt.yticks([0., .25, 0.5, 0.75, 1.0], fontsize=12)
#plt.xticks(range(1,len(activations)+1), activations, fontsize=12, rotation=45);

ax = plt.subplot(3,1,2)
vals = []
for activation in activations:
    vals.append(results['cnn-50'][activation]['match_any'])
ax.boxplot(vals);
ax.set_xticklabels([])
plt.ylabel('CNN-50', fontsize=12)
plt.yticks([0., .25, 0.5, 0.75, 1.0], fontsize=12)
#plt.xticks(range(1,len(activations)+1), activations, fontsize=12, rotation=45);

ax = plt.subplot(3,1,3)
vals = []
for activation in activations:
    vals.append(results['cnn-deep'][activation]['match_any'])
ax.boxplot(vals);
plt.ylabel('CNN-deep', fontsize=12)
plt.yticks([0., .25, 0.5, 0.75, 1.0], fontsize=12)
plt.xticks(range(1,len(activations)+1), activations, fontsize=12, rotation=45);

outfile = os.path.join(results_path, 'task1_filter_match_any_JASPAR')
fig.savefig(outfile, format='pdf', dpi=200, bbox_inches='tight')
